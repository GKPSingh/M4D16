# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y =  x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional
plt.plot(x,y);
plt.xlabel('X-axis'), plt.ylabel('Y-axis'), plt.title('Simple Plot');

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x, 'b');

# %%
x = np.linspace(0,10,15)
y =  x**2

fig, ax = plt.subplots(figsize = (10,8))
ax.plot(x,y)
ax.set(Title = 'Simple Plot', ylabel = 'Y-axis', Xlabel = 'X-axis');
ax.set(xlim=(0), ylim=(0));
# Out:
# <ipython-input-6-ff3c81db533e>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Simple Plot', ylabel = 'Y-axis', Xlabel = 'X-axis');

# %%
fig,(ax0, ax1)= plt.subplots(nrows = 2, ncols =1)
ax0.plot(x,y, 'r *')
ax1.plot(y,x, 'k--')
ax0.set(xlim=(0), ylim=(0));
ax1.set(xlim=(0), ylim=(0));

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.18, 0.55, 0.4, 0.3])
axes1.plot(x,y,'r*')
axes2.plot(y,x, 'k--')
axes1.set(Title ='XY plot', xlabel = 'X-Values', ylabel = 'Y-Values', xlim=0, ylim = 0);
axes2.set(Title ='YX plot', xlabel = 'Y-Values', ylabel = 'X-Values', xlim=0, ylim = 0);
fig.suptitle('Yahoo Plot!!!', fontsize =16, fontweight = 'bold');
# Out:
# <ipython-input-8-ddc0e1380daa>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   axes1.set(Title ='XY plot', xlabel = 'X-Values', ylabel = 'Y-Values', xlim=0, ylim = 0);
# <ipython-input-8-ddc0e1380daa>:8: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   axes2.set(Title ='YX plot', xlabel = 'Y-Values', ylabel = 'X-Values', xlim=0, ylim = 0);

# %%
fig, ax = plt.subplots(figsize = (10,8))
ax.plot(x,y);

# %%
fig,ax = plt.subplots(nrows = 3, ncols =2)
plt.tight_layout()

# %%
fig,(ax0, ax1)= plt.subplots(nrows = 2, ncols =1)
ax0.plot(x,y, 'r*')
ax1.plot(y,x, 'k--')
plt.tight_layout()

# %%
fig,(ax0, ax1)= plt.subplots(nrows = 2, ncols =1)
ax0.plot(x,y, 'r*')
ax0.set(xlim = 0, ylim=0)
ax1.plot(y,x, 'k--')
ax1.set(xlim = 0, ylim=0)
plt.tight_layout()

# %%
fig,(ax0, ax1)= plt.subplots(nrows = 2, ncols =1)
ax0.plot(x,y, 'r*')
ax0.set(xlim = 0, ylim=0)
ax1.plot(y,x, 'k--')
ax1.set(xlim = 0, ylim=0)
plt.tight_layout()

# %%
fig,(ax0, ax1)= plt.subplots(nrows = 2, ncols =1, figsize = (8,6))
ax0.plot(x,y, 'r*')
ax0.set(xlim = 0, ylim=0)
ax1.plot(y,x, 'k--')
ax1.set(xlim = 0, ylim=0)
ax0.set(Title ='XY plot', xlabel = 'X-Values', ylabel = 'Y-Values');
ax1.set(Title ='YZ plot', xlabel = 'X-Values', ylabel = 'Y-Values');
plt.tight_layout()
# Out:
# <ipython-input-14-07fbeb387ed7>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax0.set(Title ='XY plot', xlabel = 'X-Values', ylabel = 'Y-Values');
# <ipython-input-14-07fbeb387ed7>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.set(Title ='YZ plot', xlabel = 'X-Values', ylabel = 'Y-Values');

# %%
fig.savefig('Pictures.jpg', dpi=200)

# %%
fig,ax = plt.subplots(figsize = (8,6))
ax.plot(x,x**2, 'r-*', label = 'X-squared')
ax.set(xlim = 0, ylim=0)
ax.plot(x,x**3,'k--', label = 'X-Cubed')
ax.set(xlim = 0, ylim=0)
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
leg = ax.legend(loc=0, frameon=True)
plt.tight_layout();
# Out:
# <ipython-input-16-70af280760f2>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
# <ipython-input-16-70af280760f2>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');

# %%
fig,ax = plt.subplots(figsize = (8,6))
ax.plot(x,x**2, 'r-*', label = 'X-squared', linewidth = 3)
ax.set(xlim = 0, ylim=0)
ax.plot(x,x**3,'k--', label = 'X-Cubed', linewidth = 3)
ax.set(xlim = 0, ylim=0)
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
leg = ax.legend(loc=0, frameon=True)
plt.tight_layout();
# Out:
# <ipython-input-18-f4c1ab00de78>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
# <ipython-input-18-f4c1ab00de78>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');

# %%
fig,ax = plt.subplots(figsize = (8,6))
ax.plot(x,x**2, 'r-*', label = 'X-squared', linewidth = 3)
ax.set(xlim = 0, ylim=0)
ax.plot(x,x**3,'k--', label = 'X-Cubed', linewidth = 3,marker = '*', markersize = 10)
ax.set(xlim = 0, ylim=0)
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
leg = ax.legend(loc=0, frameon=True)
plt.tight_layout();
# Out:
# <ipython-input-21-43a141b373f1>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
# <ipython-input-21-43a141b373f1>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');

# %%
fig,ax = plt.subplots(figsize = (8,6))
ax.plot(x,x**2, 'r-*', label = 'X-squared', linewidth = 3)
ax.set(xlim = 0, ylim=0)
ax.plot(x,x**3,'k--', label = 'X-Cubed', linewidth = 3,marker = '*', markersize = 10, markerfacecolor = 'yellow')
ax.set(xlim = 0, ylim=0)
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
leg = ax.legend(loc=0, frameon=True)
plt.tight_layout();
# Out:
# <ipython-input-22-c2f2bef68ada>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
# <ipython-input-22-c2f2bef68ada>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title ='Plot', xlabel = 'X-Values', ylabel = 'Y-Values');
